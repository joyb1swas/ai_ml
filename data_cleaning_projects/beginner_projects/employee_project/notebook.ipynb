# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("messy_employee_dataset.xlsx")

# %%
df.to_csv("messy_employee_dataset.csv", index = False)

# %%
df
# Out:
#      EmployeeID    Name   Age Department   Salary  Experience        City  \
# 0             1  Hassan  28.0         IT  33278.0           4  Chattogram
# 1             2   Alice  58.0         HR  85302.0          38  Chattogram
# 2             3    Rita  56.0    Finance  56062.0          26  Chattogram
# 3             4     Ivy  31.0         IT  85392.0           6  Chattogram
# 4             5     Tom  27.0      Sales  77052.0           2       Dhaka
# ..          ...     ...   ...        ...      ...         ...         ...
# 300           1  Hassan  28.0         IT  33278.0           4  Chattogram
# 301           2   Alice  58.0         HR  85302.0          38  Chattogram
# 302           3    Rita  56.0    Finance  56062.0          26  Chattogram
# 303           4     Ivy  31.0         IT  85392.0           6  Chattogram
# 304           5     Tom  27.0      Sales  77052.0           2       Dhaka
#
#        JoinDate Performance
# 0    2016-11-24   Excellent
# 1    2018-09-20   Excellent
# 2    2022-10-09   Excellent
# 3    2020-02-03        Poor
# 4    2022-09-04        Poor
# ..          ...         ...
# 300  2016-11-24   Excellent
# 301  2018-09-20   Excellent
# 302  2022-10-09   Excellent
# 303  2020-02-03        Poor
# 304  2022-09-04        Poor
#
# [305 rows x 9 columns]

# %%
df.shape
# Out:
# (305, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   305 non-null    int64
#  1   Name         305 non-null    object
#  2   Age          286 non-null    float64
#  3   Department   305 non-null    object
#  4   Salary       290 non-null    float64
#  5   Experience   305 non-null    int64
#  6   City         305 non-null    object
#  7   JoinDate     305 non-null    object
#  8   Performance  305 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 21.6+ KB

# %%
df.isnull().sum()
# Out:
# EmployeeID      0
# Name            0
# Age            19
# Department      0
# Salary         15
# Experience      0
# City            0
# JoinDate        0
# Performance     0
# dtype: int64

# %%
sns.histplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.loc[df["Age"] > 100, "Age"] = np.nan

# %%
df.Age.max()
# Out:
# 60.0

# %%
df["Age"] = df['Age'].fillna(df['Age'].median())

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(data=df, x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   305 non-null    int64
#  1   Name         305 non-null    object
#  2   Age          305 non-null    float64
#  3   Department   305 non-null    object
#  4   Salary       290 non-null    float64
#  5   Experience   305 non-null    int64
#  6   City         305 non-null    object
#  7   JoinDate     305 non-null    object
#  8   Performance  305 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 21.6+ KB

# %%
df['Salary'].isnull().sum()
# Out:
# 15

# %%
sns.histplot(data=df,x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
df.Salary.describe()
# Out:
# count       290.000000
# mean      72628.400000
# std       27951.883627
# min       -5000.000000
# 25%       50067.750000
# 50%       72796.500000
# 75%       94251.500000
# max      119742.000000
# Name: Salary, dtype: float64

# %%
df.loc[df['Salary'] < 0]
# Out:
#      EmployeeID     Name   Age Department  Salary  Experience      City  \
# 118         119      Bob  29.0      Sales -5000.0           8    Khulna
# 207         208      Tom  31.0      Sales -5000.0           2  Rajshahi
# 218         219  Charlie  44.0    Finance -5000.0          20  Rajshahi
# 236         237     Nina  55.0         IT -5000.0          33     Dhaka
# 286         287    David  45.0         HR -5000.0          20     Dhaka
#
#        JoinDate Performance
# 118  2015-10-12        Good
# 207  2015-01-03   Excellent
# 218  2022-09-09   Excellent
# 236  2021-08-06     Average
# 286  2019-08-12     Average

# %%
df.loc[df["Salary"] < 0,"Salary"] = np.nan

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
sns.histplot(data=df, x="Salary")
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
df.Salary.describe()
# Out:
# count       305.000000
# mean      73948.773770
# std       25336.290505
# min       30150.000000
# 25%       52838.000000
# 50%       73357.000000
# 75%       93462.000000
# max      119742.000000
# Name: Salary, dtype: float64

# %%
df
# Out:
#      EmployeeID    Name   Age Department   Salary  Experience        City  \
# 0             1  Hassan  28.0         IT  33278.0           4  Chattogram
# 1             2   Alice  58.0         HR  85302.0          38  Chattogram
# 2             3    Rita  56.0    Finance  56062.0          26  Chattogram
# 3             4     Ivy  31.0         IT  85392.0           6  Chattogram
# 4             5     Tom  27.0      Sales  77052.0           2       Dhaka
# ..          ...     ...   ...        ...      ...         ...         ...
# 300           1  Hassan  28.0         IT  33278.0           4  Chattogram
# 301           2   Alice  58.0         HR  85302.0          38  Chattogram
# 302           3    Rita  56.0    Finance  56062.0          26  Chattogram
# 303           4     Ivy  31.0         IT  85392.0           6  Chattogram
# 304           5     Tom  27.0      Sales  77052.0           2       Dhaka
#
#        JoinDate Performance
# 0    2016-11-24   Excellent
# 1    2018-09-20   Excellent
# 2    2022-10-09   Excellent
# 3    2020-02-03        Poor
# 4    2022-09-04        Poor
# ..          ...         ...
# 300  2016-11-24   Excellent
# 301  2018-09-20   Excellent
# 302  2022-10-09   Excellent
# 303  2020-02-03        Poor
# 304  2022-09-04        Poor
#
# [305 rows x 9 columns]

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df[df.duplicated(keep=False)]
# Out:
#      EmployeeID    Name   Age Department   Salary  Experience        City  \
# 0             1  Hassan  28.0         IT  33278.0           4  Chattogram
# 1             2   Alice  58.0         HR  85302.0          38  Chattogram
# 2             3    Rita  56.0    Finance  56062.0          26  Chattogram
# 3             4     Ivy  31.0         IT  85392.0           6  Chattogram
# 4             5     Tom  27.0      Sales  77052.0           2       Dhaka
# 300           1  Hassan  28.0         IT  33278.0           4  Chattogram
# 301           2   Alice  58.0         HR  85302.0          38  Chattogram
# 302           3    Rita  56.0    Finance  56062.0          26  Chattogram
# 303           4     Ivy  31.0         IT  85392.0           6  Chattogram
# 304           5     Tom  27.0      Sales  77052.0           2       Dhaka
#
#        JoinDate Performance
# 0    2016-11-24   Excellent
# 1    2018-09-20   Excellent
# 2    2022-10-09   Excellent
# 3    2020-02-03        Poor
# 4    2022-09-04        Poor
# 300  2016-11-24   Excellent
# 301  2018-09-20   Excellent
# 302  2022-10-09   Excellent
# 303  2020-02-03        Poor
# 304  2022-09-04        Poor

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   300 non-null    int64
#  1   Name         300 non-null    object
#  2   Age          300 non-null    float64
#  3   Department   300 non-null    object
#  4   Salary       300 non-null    float64
#  5   Experience   300 non-null    int64
#  6   City         300 non-null    object
#  7   JoinDate     300 non-null    object
#  8   Performance  300 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.4+ KB

# %%
df.Name.unique()
# Out:
# array(['Hassan', 'Alice', 'Rita', 'Ivy', 'Tom', 'George', 'Charlie',
#        'Eva', 'Maya', 'Fatima', 'Omar', 'Paul', 'Quinn', 'Lina', 'Sara',
#        'Bob', 'Nina', 'Karim', 'John', 'David'], dtype=object)

# %%
df.Name.value_counts()
# Out:
# Name
# Hassan     21
# Rita       21
# Charlie    19
# Tom        18
# Nina       18
# John       17
# Sara       16
# Omar       16
# Lina       15
# Bob        15
# Ivy        15
# Maya       13
# Quinn      13
# David      13
# Fatima     12
# Alice      12
# Paul       12
# Eva        12
# George     12
# Karim      10
# Name: count, dtype: int64

# %%
df.Name.duplicated().sum()
# Out:
# 280

# %%
df.Department.unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Sales', 'Marketing', 'sales', 'marketing',
#        'it', 'hr'], dtype=object)

# %%
df.Department.value_counts()
# Out:
# Department
# Finance      65
# Sales        60
# HR           58
# Marketing    57
# IT           52
# it            3
# sales         2
# marketing     2
# hr            1
# Name: count, dtype: int64

# %%
df['Department'] = df["Department"].str.upper()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18336\971734242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department'] = df["Department"].str.upper()

# %%
df.Department.value_counts()
# Out:
# Department
# FINANCE      65
# SALES        62
# HR           59
# MARKETING    59
# IT           55
# Name: count, dtype: int64

# %%
df.City.unique()
# Out:
# array(['Chattogram', 'Dhaka', 'Rajshahi', 'Khulna', 'Sylhet', ' Khulna ',
#        ' Sylhet ', ' Chattogram ', ' Rajshahi '], dtype=object)

# %%
df.City.value_counts()
# Out:
# City
# Chattogram      65
# Khulna          64
# Rajshahi        63
# Dhaka           54
# Sylhet          44
#  Sylhet          3
#  Chattogram      3
#  Khulna          2
#  Rajshahi        2
# Name: count, dtype: int64

# %%
df['City'] = df["City"].str.strip()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18336\483809151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df["City"].str.strip()

# %%
df.City.value_counts()
# Out:
# City
# Chattogram    68
# Khulna        66
# Rajshahi      65
# Dhaka         54
# Sylhet        47
# Name: count, dtype: int64

# %%
df.JoinDate.unique()
# Out:
# array(['2016-11-24', '2018-09-20', '2022-10-09', '2020-02-03',
#        '2022-09-04', '2018-12-03', '2019-08-21', '2024-11-06',
#        '2020-01-08', '2020-04-21', '2018-12-18', '2017-09-16',
#        '2016-07-13', '2019-11-11', '2023-03-17', '2020-03-18',
#        '2019-04-02', '2017-03-22', '2018-09-25', '2022-02-08',
#        '2024-04-01', '2023-04-09', '2018-08-26', '2021-08-28',
#        '2018-04-18', '2016-08-26', '2017-07-16', '2021-05-26',
#        '2023-03-02', '2016-10-08', '2020-05-07', '2020-02-01',
#        '2023-05-05', '2023-12-10', '2016-02-24', '2019-09-16',
#        '2015-06-25', '2015-02-03', '2021-03-02', '2020-09-28',
#        '2015-03-24', '2021-01-28', '2018-01-22', '2023-07-22',
#        '2015-02-20', '2021-10-07', '2020-07-03', '2019-11-14',
#        '2021-11-24', '2019-05-07', '2022-11-07', '2020-02-27',
#        '2018-08-20', '2022-07-08', '2022-01-18', '2024-06-25',
#        '2022-08-09', '2016-12-10', '2017-04-13', '2022-07-02',
#        '2022-01-12', '2022-04-09', '2022-03-20', '2017-08-06',
#        '2020-07-09', '2017-04-05', '2017-10-20', '2024-11-13',
#        '2024-02-26', '2020-01-28', '2021-03-24', '2019-06-28',
#        '2020-05-11', '2016-04-24', '2015-02-10', '2023-09-12',
#        '2019-04-04', '2022-05-24', '2019-01-23', '2022-02-28',
#        '2017-01-09', '2015-03-05', '2024-10-08', '2024-10-02',
#        '2018-03-18', '2019-01-08', '2018-07-04', '2019-10-24',
#        '2023-09-16', '2019-01-03', '2017-08-17', '2022-06-14',
#        '2022-05-22', '2020-02-25', '2015-04-17', '2019-09-05',
#        '2017-05-18', '2016-11-27', '2022-04-15', '2019-07-11',
#        '2017-08-18', '2020-04-23', '2022-12-26', '2017-09-19',
#        '2017-07-28', '2016-06-28', '2016-04-21', '2017-12-10',
#        '2021-03-08', '2024-07-20', '2022-06-19', '2021-05-01',
#        '2018-11-07', '2015-10-12', '2017-09-12', '2022-02-05',
#        '2019-09-04', '2020-02-22', '2018-11-03', '2015-05-16',
#        '2020-11-24', '2021-05-02', '2020-09-21', '2016-11-07',
#        '2016-09-07', '2017-03-18', '2020-04-19', '2023-02-24',
#        '2022-09-08', '2021-07-22', '2017-02-05', '2024-09-10',
#        '2018-07-15', '2020-07-11', '2016-02-14', '2023-06-22',
#        '2024-05-12', '2024-10-22', '2019-06-12', '2015-02-24',
#        '2019-12-11', '2019-08-22', '2023-02-12', '2017-05-10',
#        '2021-09-23', '2015-07-01', '2021-05-04', '2016-07-28',
#        '2021-05-24', '2023-09-07', '2019-04-06', '2024-08-22',
#        '2019-05-19', '2015-01-12', '2021-08-19', '2022-09-05',
#        '2015-04-23', '2020-05-13', '2020-02-18', '2016-10-22',
#        '2016-05-18', '2023-06-01', '2018-03-05', '2020-10-05',
#        '2015-07-12', '2018-05-26', '2019-07-17', '2022-06-18',
#        '2015-07-17', '2022-08-20', '2024-09-14', '2021-11-26',
#        '2023-10-08', '2024-07-06', '2023-09-01', '2015-06-26',
#        '2017-01-12', '2016-12-25', '2020-05-17', '2021-06-06',
#        '2016-07-20', '2019-05-15', '2024-07-09', '2017-01-05',
#        '2021-10-02', '2024-05-23', '2022-02-26', '2017-12-23',
#        '2018-08-01', '2024-02-03', '2016-03-11', '2023-11-19',
#        '2017-05-06', '2019-04-21', '2023-11-06', '2015-01-03',
#        '2024-11-01', '2021-05-15', '2018-06-20', '2023-09-04',
#        '2017-02-02', '2024-12-11', '2022-01-03', '2015-01-10',
#        '2015-02-14', '2015-10-18', '2022-09-09', '2020-03-07',
#        '2022-09-15', '2017-07-20', '2024-05-16', '2019-12-28',
#        '2015-10-16', '2015-10-23', '2021-12-07', '2018-09-11',
#        '2020-09-12', '2019-04-10', '2019-05-04', '2016-06-15',
#        '2019-03-04', '2017-07-21', '2015-02-21', '2021-08-06',
#        '2020-05-15', '2020-03-24', '2018-03-20', '2017-03-16',
#        '2019-06-10', '2022-05-06', '2018-04-05', '2022-09-26',
#        '2023-12-12', '2024-09-05', '2022-02-17', '2024-01-18',
#        '2024-02-02', '2015-05-14', '2022-07-13', '2023-07-17',
#        '2021-09-13', '2016-01-26', '2024-01-15', '2018-01-05',
#        '2018-05-05', '2017-11-22', '2020-12-14', '2018-04-10',
#        '2023-03-13', '2016-09-24', '2016-04-26', '2018-12-04',
#        '2023-08-15', '2015-10-28', '2021-05-05', '2023-11-22',
#        '2020-03-05', '2016-11-02', '2015-01-18', '2015-09-27',
#        '2018-10-17', '2022-10-08', '2021-07-18', '2024-08-09',
#        '2017-06-01', '2024-04-19', '2020-01-04', '2021-06-01',
#        '2021-03-22', '2019-03-13', '2019-08-12', '2023-09-17',
#        '2024-10-26', '2023-04-19', '2022-03-03', '2020-05-08',
#        '2019-01-13', '2024-03-10', '2020-05-24', '2020-02-19',
#        '2018-05-22', '2024-07-18', '2016-04-22'], dtype=object)

# %%
df.JoinDate.value_counts()
# Out:
# JoinDate
# 2017-09-12    2
# 2024-11-13    2
# 2016-06-28    2
# 2020-02-27    2
# 2021-11-26    2
#              ..
# 2017-12-10    1
# 2021-03-08    1
# 2024-07-20    1
# 2022-06-19    1
# 2016-04-22    1
# Name: count, Length: 283, dtype: int64

# %%
df.Performance.unique()
# Out:
# array(['Excellent', 'Poor', 'Average', 'Good'], dtype=object)

# %%
df.Performance.value_counts()
# Out:
# Performance
# Poor         95
# Good         71
# Average      69
# Excellent    65
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        EmployeeID         Age         Salary  Experience
# count  300.000000  300.000000     300.000000  300.000000
# mean   150.500000   41.466667   74057.633333   16.263333
# std     86.746758   11.127216   25399.741829   11.440437
# min      1.000000   21.000000   30150.000000    0.000000
# 25%     75.750000   32.000000   52682.500000    6.000000
# 50%    150.500000   41.000000   73357.000000   15.000000
# 75%    225.250000   51.000000   93660.000000   26.000000
# max    300.000000   60.000000  119742.000000   39.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   300 non-null    int64
#  1   Name         300 non-null    object
#  2   Age          300 non-null    float64
#  3   Department   300 non-null    object
#  4   Salary       300 non-null    float64
#  5   Experience   300 non-null    int64
#  6   City         300 non-null    object
#  7   JoinDate     300 non-null    object
#  8   Performance  300 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.4+ KB

# %%
df.isnull().sum()
# Out:
# EmployeeID     0
# Name           0
# Age            0
# Department     0
# Salary         0
# Experience     0
# City           0
# JoinDate       0
# Performance    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Age'].describe()
# Out:
# count    300.000000
# mean      41.466667
# std       11.127216
# min       21.000000
# 25%       32.000000
# 50%       41.000000
# 75%       51.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
df["Salary"].describe()
# Out:
# count       300.000000
# mean      74057.633333
# std       25399.741829
# min       30150.000000
# 25%       52682.500000
# 50%       73357.000000
# 75%       93660.000000
# max      119742.000000
# Name: Salary, dtype: float64

# %%
df
# Out:
#      EmployeeID    Name   Age Department    Salary  Experience        City  \
# 0             1  Hassan  28.0         IT   33278.0           4  Chattogram
# 1             2   Alice  58.0         HR   85302.0          38  Chattogram
# 2             3    Rita  56.0    FINANCE   56062.0          26  Chattogram
# 3             4     Ivy  31.0         IT   85392.0           6  Chattogram
# 4             5     Tom  27.0      SALES   77052.0           2       Dhaka
# ..          ...     ...   ...        ...       ...         ...         ...
# 295         296    Maya  57.0      SALES   61775.0          32      Khulna
# 296         297    Rita  58.0         HR  101516.0          36      Khulna
# 297         298    Paul  41.0         IT   83627.0           0      Sylhet
# 298         299    Omar  48.0  MARKETING   79412.0          27      Khulna
# 299         300    Rita  55.0  MARKETING   34818.0          30       Dhaka
#
#        JoinDate Performance
# 0    2016-11-24   Excellent
# 1    2018-09-20   Excellent
# 2    2022-10-09   Excellent
# 3    2020-02-03        Poor
# 4    2022-09-04        Poor
# ..          ...         ...
# 295  2020-02-19        Good
# 296  2018-08-26     Average
# 297  2018-05-22        Good
# 298  2024-07-18        Poor
# 299  2016-04-22     Average
#
# [300 rows x 9 columns]

# %%
df.to_csv("cleaned_employee_dataset.csv", index=False)
